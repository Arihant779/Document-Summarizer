# %%
# !pip install transformers
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
text = """
Adolf Hitler: The Rise, Ideology, and Impact of a Twentieth-Century Dictator

Adolf Hitler, born on April 20, 1889, in Braunau am Inn, Austria-Hungary, is one of the most notorious figures in modern history. His impact on the world, particularly during the 1930s and 1940s, continues to shape global perspectives on nationalism, fascism, and the consequences of unchecked authoritarianism. This essay explores Hitler’s life, his ideological foundations, the circumstances that propelled him to power, his policies, and the devastating legacy he left behind.

Early Life and Background
Adolf Hitler was born to Alois Hitler and Klara Pölzl. His father was a customs official, and his mother was from a peasant background. Hitler’s childhood was marked by several familial tragedies, including the deaths of his siblings and his father. After his father’s death in 1903, Hitler moved to Vienna, where he struggled as a young artist and developed strong nationalist and anti-Semitic views. His experiences in Vienna, a hotbed of ethnic tensions and political radicalism, deeply influenced his later ideological beliefs.

Formation of Ideology
Hitler’s worldview was shaped by a combination of factors: his experiences in Vienna, exposure to nationalist literature, and resentment towards the Treaty of Versailles and the perceived betrayal of Germany during World War I. Central to Hitler’s ideology was an extreme form of nationalism, which glorified the Germanic "Aryan" race as superior, and a virulent anti-Semitism, blaming Jews for many of Germany’s social, economic, and political problems.

Rise to Power
Following World War I, Germany was in a state of economic and political turmoil. The Weimar Republic, established in 1919, faced challenges from both the extreme left (Communists) and the extreme right (nationalists and fascists). Hitler joined the German Workers’ Party (DAP) in 1919, which later became the National Socialist German Workers’ Party (NSDAP or Nazi Party). His charismatic speaking ability and radical ideas quickly gained him a following.

The Munich Beer Hall Putsch of 1923, although unsuccessful, brought Hitler national attention. During his imprisonment, he wrote "Mein Kampf," outlining his political ideology and strategies for Germany’s future. By the early 1930s, the Nazis had become a significant political force, capitalizing on widespread discontent with the Weimar Republic and the Great Depression. In 1933, Hitler was appointed Chancellor of Germany by President Paul von Hindenburg, marking the beginning of his consolidation of power.

Policies and Actions
Once in power, Hitler swiftly transformed Germany into a totalitarian state. He dismantled democratic institutions, suppressed political opposition, and established the Gestapo (Secret State Police) to eliminate dissent. The Nuremberg Laws of 1935 stripped Jews of their citizenship and rights, paving the way for increasingly harsh persecution. Hitler’s aggressive foreign policy aimed to overturn the Treaty of Versailles and expand German territory, leading to the annexation of Austria (Anschluss) in 1938 and the invasion of Poland in 1939, triggering World War II.

World War II and Holocaust
Hitler’s aggressive expansionist policies plunged Europe into a devastating conflict. The Holocaust, Hitler’s systematic genocide of six million Jews and millions of others deemed "undesirable" by Nazi ideology, remains one of the darkest chapters in human history. Concentration camps such as Auschwitz-Birkenau became symbols of the Nazis’ brutality and the industrialized murder of millions.

Downfall and Legacy
The tide of World War II turned against Germany in 1942, following defeats in Stalingrad and El Alamein. Allied forces, led by the United States, Soviet Union, and Great Britain, launched a coordinated assault that culminated in Hitler’s suicide in his Berlin bunker on April 30, 1945. Germany surrendered unconditionally on May 7, 1945, marking the end of the Nazi regime.

Hitler’s legacy is complex and continues to evoke strong emotions. His crimes against humanity and the devastation wrought by World War II led to a profound reevaluation of nationalism, racism, and the dangers of unchecked authoritarianism. The Nuremberg Trials held after the war established principles of international justice and accountability for war crimes.

Conclusion
Adolf Hitler’s life and actions represent a cautionary tale about the dangers of totalitarianism, xenophobia, and unchecked political power. His rise to power and the horrors of the Holocaust serve as stark reminders of the consequences of hatred and discrimination. Understanding Hitler’s ideology and impact is essential for grappling with the complexities of modern history and ensuring that such atrocities are never repeated.

In conclusion, Adolf Hitler’s influence on the twentieth century cannot be overstated. From his early life in Austria to his catastrophic reign as dictator of Nazi Germany, Hitler’s actions continue to reverberate through history. His ideology, policies, and the genocide he orchestrated during World War II remain chilling reminders of the darkest potentials of human nature.
"""

# %%
len(text)
# Out:
# 5178

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config
model_name = "t5-small"
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# ...

# %%
def T5_GenerateSummary(text):
  preprocessed_text = text.strip().replace('\n','')
  t5_input_text = 'summarize: ' + preprocessed_text
  tokenized_text = tokenizer.encode(t5_input_text, return_tensors='pt', max_length=512).to(device)
  summary_ids = model.generate(tokenized_text, min_length=50, max_length=100)
  summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
  return summary

# %%
sum = T5_GenerateSummary(text)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
# Out:
# 'Hitler was born on April 20, 1889 in Braunau am Inn, Austria-Hungary. his influence on the world continues to shape global perspectives on nationalism. his experiences in Vienna, exposure to nationalist literature, and resentment towards the Treaty of Versailles.'

# %%
# !pip install opencv-python pytesseract numpy

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alex-p/tesseract-ocr
# !apt-get update -qq
# !apt-get install -y -qq tesseract-ocr
# !apt-get install -y -qq libtesseract-dev
# !pip install pytesseract
# !pip install opencv-python
# Out:
# E: Package 'python-software-properties' has no installation candidate
# E: Package 'module-init-tools' has no installation candidate
# Repository: 'deb https://ppa.launchpadcontent.net/alex-p/tesseract-ocr/ubuntu/ jammy main'
# Description:
#  The Tesseract OCR engine was one of the top 3 engines in the 1995
#  UNLV Accuracy test. Between 1995 and 2006 it had little work done on
#  it, but since then it has been improved extensively by Google and is
#  probably one of the most accurate open source OCR engines
#  available. It can read a wide variety of image formats and convert
#  them to text in over 40 languages. This package includes the command
#  line tool.
# More info: https://launchpad.net/~alex-p/+archive/ubuntu/tesseract-ocr
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/alex-p-ubuntu-tesseract-ocr-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/alex-p-ubuntu-tesseract-ocr-jammy.list
# ...

# %%
import cv2
import pytesseract
from google.colab.patches import cv2_imshow  # Required for displaying images in Colab

# Path to Tesseract executable (if not in your PATH environment variable)
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %%
img = cv2.imread('/content/1131w-zvoLwRH8Wys.webp')

# %%
import matplotlib.pyplot as plt

# %%
img.shape
# Out:
# (1600, 1131, 3)

# %%
plt.imshow(img)

# %%
img = cv2.imread('/content/receipt1.png')




# Perform OCR using Tesseract
extracted_text = pytesseract.image_to_string(img)

# %%
print(extracted_text)
# Out:
# invoice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FROM INVOICE # us-001
# East Repair Inc. INVOICE DATE 1102/2019
# 1912 Harvest Lane P.O.# 2312/2019
# New York, NY 12210
# DUE DATE 26/02/2019
# BILL TO SHIP TO
# John Smith John Smith
# 2. Court Square 3787 Pineview Drive
# New York, NY 12210 ‘Cambridge, MA 12210
# QTY DESCRIPTION UNIT PRICE AMOUNT
# 1 Front and rear brake cables 100.00 100.00
# 2 New set of pedal arms 15.00 30.00
# 3 Labor 3hrs, 5.00 1.00
# Subtotal 145.00
# Sales Tax 6.25% 9.06
#
# TOTAL $154.06
#
# TERMS & CONDITIONS
#
# Payment is due within 15 days
#
# Please make checks payable to: East Repair Inc.
#
# Smith,

# %%
def f1(text):
  preprocessed_text = text.strip().replace('\n','')
  t5_input_text = 'summarize: ' + preprocessed_text
  tokenized_text = tokenizer.encode(t5_input_text, return_tensors='pt', max_length=512).to(device)
  summary_ids = model.generate(tokenized_text, min_length=20, max_length=30)
  summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
  return summary

# %%
sum = f1(extracted_text)

# %%
sum
# Out:
# 'QTY DESCRIPTION UNIT PRICE AMOUNT1 Front and rear brake cables 100.00 100.002 New set of pedal arms'

# %%
import spacy

# Load spaCy model for English
nlp = spacy.load('en_core_web_sm')

# Example text (replace with your bill text)
text = extracted_text

# Process the text with spaCy
doc = nlp(text)

# Extract entities
entities = [(ent.text, ent.label_) for ent in doc.ents]
print(entities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c9028e7ff4b0> in <cell line: 7>()
#       5
#       6 # Example text (replace with your bill text)
# ----> 7 text = extracted_text
#       8
#       9 # Process the text with spaCy
#
# NameError: name 'extracted_text' is not defined

# %%
# Extracted entities from spaCy
bill_to = next((entity[0] for entity in entities if entity[1] == 'PERSON'), 'N/A').strip().replace("\n"," ")
company_name = next((entity[0] for entity in entities if entity[1] == 'ORG'), 'N/A').strip().replace("\n"," ")
bill_date = next((entity[0] for entity in entities if entity[1] == 'DATE'), 'N/A').strip().replace("\n"," ")
entities.reverse()
total_amount = next((entity[0] for entity in entities if entity[1] == 'MONEY'), 'N/A').strip().replace("\n"," ")

# Generate a structured summary
summary = f"This is a tax invoice issued to {bill_to} and charged by {company_name}.\n"
summary += f"The invoice was issued on {bill_date} with a total amount of {total_amount}."


print(summary)
# Out:
# This is a tax invoice issued to John Smith and charged by East Repair Inc..
# The invoice was issued on 1102/2019 with a total amount of 154.06.

# %%
import json
import requests

url = "https://ocr.asprise.com/api/v1/receipt"

image = "receipt3.jpg"

res = requests.post(url,

data = {

'api_key': 'TEST',

'recognizer': 'auto',

'ref_no': 'oct_python_123'

},

files = {

'file': open(image, 'rb')

})


with open( "response1.json",'w') as f:
    json.dump(json.loads(res.text),f)

with open("response1.json",'r') as f:
    data = json.load(f)

bill = data['receipts'][0]

name = bill['merchant_name'].strip().replace("\n",'')

summary = f"This is a tax invoice issued to {name} dated {bill['date']}.\n"
summary += f"The invoice was issued for purchase of a total of {len(bill['items'])} for price {bill['total']}.\n"
summary += f"Items were bought with the receipt number {bill['receipt_no']} "

print(summary)

# %% [markdown]
# Table Summary From here

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load the image
image = cv2.imread('/content/3S1Ii.jpg')

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply GaussianBlur to reduce noise
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply adaptive thresholding
thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 11, 4)

# Display the processed image
cv2_imshow( thresh)
# Out:
# <PIL.Image.Image image mode=L size=465x556>

# %%
# Find contours
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sort contours by area and find the largest contour (assumed to be the table)
contours = sorted(contours, key=cv2.contourArea, reverse=True)
largest_contour = contours[0]

# Draw contours (optional for visualization)
cv2.drawContours(image, [largest_contour], -1, (0, 255, 0), 2)

# Display the image with contours
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=465x556>

# %%
# Get bounding box coordinates
x, y, w, h = cv2.boundingRect(largest_contour)

# Crop the table region from the original image
table_region = image[y:y+h, x:x+w]

# Display the extracted table region
cv2_imshow( table_region)
# Out:
# <PIL.Image.Image image mode=RGB size=437x522>

# %%
img_2 = table_region

# %%
# Perform OCR using Tesseract
extracted_text = pytesseract.image_to_string(img_2)

# %%
extracted_text
# Out:
# ' \n\n \n\n \n\n \n\nAuthors: ‘Lot Size Model | Inventory ‘Carbon Emission and\nCost Terms Environmental Cost\nTerms\nHua etal EOQ model ‘Order ost Carbon emission\noun. Inventory holding | from logistie and\ncost warehouse is linear\ninthe order quantity\nWahab etal | EOQiKe model _| Setup cost Catbon emission\neon and extension to | Inventory holding cos | from transportation\nJELS-like model | Transportation cost | includes fixed cost,\nfor supply chains Screening cost and variable cost\nChenetal. | EOQmodel and | Fixed ordering cost | Carbon emission\n2010) extension to Inventory holding cost | associated with\n\nfacility location\nmodel and\n\nsnewsvendor model\n\nPurchasing cost\n\nordering is EOQ-tike\n‘model and captured\n\nin the constraints to\n\n \n\n \n\n \n\nthe EOQ mode!\nBenjaafar etal. | EOQ model and | Fixed ordering cost | Carbon emission\n2010) extension to Variable ordering | associated with ordering\ncollaboration of | cost is EOQUike model and\nsupply chains | I
# ...

# %%
rows = extracted_text.strip().split('\n')

# %%
rows
# Out:
# ['facility location',
#  'model and',
#  '',
#  'snewsvendor model',
#  '',
#  ' ',
#  '',
#  'Purchasing cost',
#  '',
#  'Authors: ‘Lot Size Model | Inventory ‘Carbon Emission and',
#  'Cost Terms Environmental Cost',
#  'Terms',
#  'Hua etal EOQ model ‘Order ost Carbon emission',
#  'oun. Inventory holding | from logistie and',
#  'cost warehouse is linear',
#  'inthe order quantity',
#  'Wahab etal | EOQiKe model _| Setup cost Catbon emission',
#  'eon and extension to | Inventory holding cos | from transportation',
#  'JELS-like model | Transportation cost | includes fixed cost,',
#  'for supply chains Screening cost and variable cost',
#  'Chenetal. | EOQmodel and | Fixed ordering cost | Carbon emission',
#  '2010) extension to Inventory holding cost | associated with',
#  '',
#  ' ',
#  '',
#  'ordering is EOQ-tike',
#  '‘model and captured',
#  '',
#  'in the constraints to',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  'Backlog cost',
# ...

# %%
pip install -U ExtractTable
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('/content/3S1Ii.jpg')
plt.imshow(img)

# %%
from ExtractTable import ExtractTable
et_sess = ExtractTable(api_key='pYtILWEFaaOju5DzN5tbiNDYCTF4jWkBMiBhl8Tf')        # Replace your VALID API Key here
print(et_sess.check_usage())        # Checks the API Key validity as well as shows associated plan usage
table_data = et_sess.process_file(filepath='/content/3S1Ii.jpg', output_format="df")

# To process PDF, make use of pages ("1", "1,3-4", "all") params in the read_pdf function
# table_data = et_sess.process_file(filepath=Location_of_PDF_with_Tables, output_format="df", pages="all")
# Out:
# {'credits': 10, 'used': 0, 'queued': 0}

# %%
data = np.array(table_data)

# %%
data.shape
# Out:
# (1, 5, 4)

# %%
data[0][0]
# Out:
# array(['Authors', 'Lot Size Model', 'Inventory Cost Terms',
#        'Carbon Emission and Environmental Cost Terms'], dtype=object)

# %%
table_summary = f"The following table contains {data.shape[2]} columns corresponding to "
for heading in data[0][0][:-1]:
  table_summary += f"'{heading}', "

if data.shape[2]!=1:
  table_summary+= "and "

table_summary += f"'{data[0][0][-1]}'."
table_summary += "\n"

table_summary += "The first row of the table shows that "
for i in range(data.shape[2] - 1):
  table_summary += f"'{data[0][0][i]}' - '{data[0][1][i]}' , "

if data.shape[2]!=1:
  table_summary+= "and "

table_summary += f"'{data[0][0][data.shape[2] - 1]}' - '{data[0][1][data.shape[2] - 1]}'. "



print(table_summary)
# Out:
# The following table contains 4 columns corresponding to 'Authors', 'Lot Size Model', 'Inventory Cost Terms', and 'Carbon Emission and Environmental Cost Terms'.
# The first row of the table shows that 'Authors' - 'Hua et al. (2011).' , 'Lot Size Model' - 'EOQ model' , 'Inventory Cost Terms' - 'Order cost Inventory holding cost' , and 'Carbon Emission and Environmental Cost Terms' - 'Carbon emission from logistic and warehouse is linear in the order quantity'.
