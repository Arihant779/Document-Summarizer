# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install rake-nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.1 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import textwrap
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline
from rake_nltk import Rake
from transformers import pipeline, AutoTokenizer
# Out:
# 2024-07-13 09:10:52.477746: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-13 09:10:52.477879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-13 09:10:52.660461: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def similarity(paragraph1,paragraph2):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([paragraph1, paragraph2])
    cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])
    return cosine_sim

# %%
# def generate_title(text):

# %%
tt="""Renewable energy is becoming increasingly important as the world seeks to reduce its reliance on fossil fuels. Solar power, harnessed through photovoltaic cells, converts sunlight directly into electricity. These cells are made of semiconductor materials, such as silicon, which absorb photons and release electrons. This process creates an electric current that can be used to power homes and businesses.\n\nWind energy is another major player in the renewable sector. Wind turbines, often seen in large clusters called wind farms, capture the kinetic energy of the wind. The turbine blades turn a rotor, which spins a generator to produce electricity. Wind power is highly efficient in areas with strong, consistent winds, such as coastal regions and open plains.\n\nHydropower is generated by harnessing the energy of flowing water. This can be done on a large scale with dams, where water released from the reservoir flows through turbines to generate electricity. Small-scale hydropower systems can also be implemented in rivers and streams, providing localized energy solutions.\n\nGeothermal energy taps into the Earth's internal heat. This heat originates from the radioactive decay of minerals and the original formation of the planet. Geothermal plants convert this heat into electricity by pumping water into the Earth's crust, where it is heated and then returned to the surface as steam. The steam drives a turbine connected to a generator, producing electricity.\n\nBiomass energy is derived from organic materials, such as plant and animal waste. This biomass can be burned directly for heat, or converted into biofuels like ethanol and biodiesel. These fuels can be used in vehicles, reducing dependence on traditional gasoline and diesel.\n\nEnergy efficiency is a crucial aspect of the transition to renewable energy. Efficient appliances, improved insulation, and smart grid technologies help reduce overall energy consumption. By using energy more wisely, we can lower our environmental impact and make the most of renewable resources.\n\nElectric vehicles (EVs) are gaining popularity as a sustainable alternative to gasoline-powered cars. EVs run on electricity stored in batteries, which can be charged using renewable energy sources. They produce zero emissions during operation, making them an environmentally friendly option for transportation.\n\nThe integration of renewable energy into the existing power grid presents challenges. Intermittency is a significant issue, as solar and wind power are not always available. Advances in energy storage technology, such as batteries and pumped hydro storage, are helping to address this problem. These systems store excess energy when production is high and release it when demand increases.\n\nGovernment policies and incentives play a vital role in the adoption of renewable energy. Subsidies, tax credits, and renewable energy mandates encourage investment in clean energy technologies. International agreements, like the Paris Agreement, aim to limit global warming by reducing greenhouse gas emissions.\n\nPublic awareness and education are also essential. By understanding the benefits of renewable energy and the need for sustainable practices, individuals can make informed choices that contribute to a greener future. Simple actions, like conserving energy at home and supporting renewable energy initiatives, can have a significant impact."""

# %%
para2="These cells are made of semiconductor materials, such as silicon, which absorb photons and release electrons. This process creates an electric current that can be used to power homes and businesses."
para1="Renewable energy is becoming increasingly important as the world seeks to reduce its reliance on fossil fuels. Solar power, harnessed through photovoltaic cells, converts sunlight directly into electricity. "

# %%
similarity(para1,para2)
# Out:
# array([[0.0712638]])

# %%
tt1="""Renewable energy is becoming increasingly important as the world seeks to reduce its reliance on fossil fuels. Solar power, harnessed through photovoltaic cells, converts sunlight directly into electricity. These cells are made of semiconductor materials, such as silicon, which absorb photons and release electrons. This process creates an electric current that can be used to power homes and businesses.

Wind energy is another major player in the renewable sector. Wind turbines, often seen in large clusters called wind farms, capture the kinetic energy of the wind. The turbine blades turn a rotor, which spins a generator to produce electricity. Wind power is highly efficient in areas with strong, consistent winds, such as coastal regions and open plains.

Hydropower is generated by harnessing the energy of flowing water. This can be done on a large scale with dams, where water released from the reservoir flows through turbines to generate electricity. Small-scale hydropower systems can also be implemented in rivers and streams, providing localized energy solutions.

Geothermal energy taps into the Earth's internal heat. This heat originates from the radioactive decay of minerals and the original formation of the planet. Geothermal plants convert this heat into electricity by pumping water into the Earth's crust, where it is heated and then returned to the surface as steam. The steam drives a turbine connected to a generator, producing electricity.

Biomass energy is derived from organic materials, such as plant and animal waste. This biomass can be burned directly for heat, or converted into biofuels like ethanol and biodiesel. These fuels can be used in vehicles, reducing dependence on traditional gasoline and diesel.

Energy efficiency is a crucial aspect of the transition to renewable energy. Efficient appliances, improved insulation, and smart grid technologies help reduce overall energy consumption. By using energy more wisely, we can lower our environmental impact and make the most of renewable resources.

Electric vehicles (EVs) are gaining popularity as a sustainable alternative to gasoline-powered cars. EVs run on electricity stored in batteries, which can be charged using renewable energy sources. They produce zero emissions during operation, making them an environmentally friendly option for transportation.

The integration of renewable energy into the existing power grid presents challenges. Intermittency is a significant issue, as solar and wind power are not always available. Advances in energy storage technology, such as batteries and pumped hydro storage, are helping to address this problem. These systems store excess energy when production is high and release it when demand increases.

Government policies and incentives play a vital role in the adoption of renewable energy. Subsidies, tax credits, and renewable energy mandates encourage investment in clean energy technologies. International agreements, like the Paris Agreement, aim to limit global warming by reducing greenhouse gas emissions.

Public awareness and education are also essential. By understanding the benefits of renewable energy and the need for sustainable practices, individuals can make informed choices that contribute to a greener future. Simple actions, like conserving energy at home and supporting renewable energy initiatives, can have a significant impact."""

# %%
##problems that can be encountered
# paragraph is of large length
# paragraph too short
# paragraph

# %%
def text_to_list(text):
    sentences = text.split('.')
    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    return sentences

# %%
def form_contexts(text,alpha):
    new_text=text_to_list(text)
    contexts=[]
    curr=[new_text[0]]
    for i in range(len(new_text)-1):
        value=similarity(new_text[i],new_text[i+1])
#         print(value)
        if value>alpha:
            curr.append(new_text[i+1])
        else:
            para = '. '.join(curr) + '.'
            if(len(para)>30):
                contexts.append(para)
            curr.clear()
            curr.append(new_text[i+1])   
    if curr:
        para = '. '.join(curr) + '.'
        contexts.append(para)
    return contexts

# %%
k=form_contexts(tt,0.03)
print(k[9])
print(len(k))
print(len(tt1))
# Out:
# International agreements, like the Paris Agreement, aim to limit global warming by reducing greenhouse gas emissions.
# 11
# 3403

# %%
model_name='facebook/bart-large-cnn'
tokenizer = AutoTokenizer.from_pretrained(model_name)
summarizer = pipeline('summarization', model=model_name)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
def count_tokens(text):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tokens = tokenizer.encode(text, add_special_tokens=True)
    num_tokens = len(tokens)
    return num_tokens

def generate_bullet_point(text):
    num_tokens = count_tokens(text)
    max_length = max(num_tokens // 2, 1)
    summarizer = pipeline('summarization', model=model_name)
    summary = summarizer(text, max_length=max_length, min_length=0, do_sample=False)
    bullet_points = [sentence.strip() for sentence in summary[0]['summary_text'].split('. ') if sentence]
    
    rake = Rake()
    rake.extract_keywords_from_text(summary[0]['summary_text'])
    title = rake.get_ranked_phrases()[0] if rake.get_ranked_phrases() else "No title found"
    
    return bullet_points, title

# %%
# def generate_bullet_point(text):
#     summarizer = pipeline('summarization')
#     summary = summarizer(text, max_length=len(text)/4, min_length=5, do_sample=False)
#     bullet_points=[]
#     for sentence in summary[0]['summary_text'].split('. '):
#         bullet_points.append(sentence)
#     rake = Rake()
# #     rake.extract_keywords_from_text(summary[0]['summary_text'])
#     rake.extract_keywords_from_text(text)
#     title = rake.get_ranked_phrases()[0] 
#     return bullet_points, title

# %%
a,b=generate_bullet_point(k[0])

# %%
print(b)
# Out:
# becoming increasingly important

# %%
para1='becoming increasingly important'
similarity(b[4],k[0])
# Out:
# array([[0.]])

# %%
def wrap_text(text, width):
    return '\n'.join(textwrap.wrap(text, width))

# %%
def get_bbox_center(text_obj):
    bbox = text_obj.get_window_extent(renderer=ax.get_figure().canvas.get_renderer())
    bbox_data = bbox.transformed(ax.transData.inverted())
    x_center = (bbox_data.x0 + bbox_data.x1) / 2
    y_center = (bbox_data.y0 + bbox_data.y1) / 2
    return x_center, y_center

# %%
def connect(ax,text_obj1,text_obj2):
    x1, y1 = get_bbox_center(text_obj1)
    x2, y2 = get_bbox_center(text_obj2)
    ax.plot([x2, x1], [y2, y1], 'k-')

# %%
# def connect(ax, text_obj1, text_obj2):
#     x1, y1 = get_bbox_center(text_obj1)
#     x2, y2 = get_bbox_center(text_obj2)
    
#     # Extend line if the text objects are outside the axes
#     xlim = ax.get_xlim()
#     ylim = ax.get_ylim()
    
#     if x1 < xlim[0] or x1 > xlim[1] or y1 < ylim[0] or y1 > ylim[1]:
#         x1 = max(min(x1, xlim[1]), xlim[0])
#         y1 = max(min(y1, ylim[1]), ylim[0])
    
#     if x2 < xlim[0] or x2 > xlim[1] or y2 < ylim[0] or y2 > ylim[1]:
#         x2 = max(min(x2, xlim[1]), xlim[0])
#         y2 = max(min(y2, ylim[1]), ylim[0])
    
#     ax.plot([x1, x2], [y1, y2], 'k-')

# %%
# def connect(ax, text_obj1, text_obj2):
#     x1, y1 = get_bbox_center(text_obj1)
#     x2, y2 = get_bbox_center(text_obj2)
    
#     # Draw an annotation line
#     ax.annotate('', xy=(x2, y2), xytext=(x1, y1),
#                 arrowprops=dict(arrowstyle='->', color='black'))

# %%
# def get_top_center(text_obj):
#     bbox = text_obj.get_bbox_patch().get_bbox()
#     x_center = (bbox.x0 + bbox.x1) / 2
#     y_top = bbox.y1
#     return (x_center, y_top)

# # Function to get the bottom center of the bounding box
# def get_bottom_center(text_obj):
#     bbox = text_obj.get_bbox_patch().get_bbox()
#     x_center = (bbox.x0 + bbox.x1) / 2
#     y_bottom = bbox.y0
#     return (x_center, y_bottom)

# # Function to connect top center of text_obj1 to bottom center of text_obj2
# def connect(ax, text_obj1, text_obj2):
#     x1, y1 = get_top_center(text_obj1)
#     x2, y2 = get_bottom_center(text_obj2)
    
#     # Draw an annotation line
#     ax.annotate('', xy=(x2, y2), xytext=(x1, y1),
#                 arrowprops=dict(arrowstyle='->', color='black'))

# %%
def para(ax,x,y,text,body1,width,gap,fsize):
    bullet_points,title=generate_bullet_point(text)
    if bullet_points:
        text_obj1=ax.text(x, y, wrap_text(title,width), fontsize=fsize+1,
                   ha='center', va='center', rotation=0,
                   bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))
        connect(ax,text_obj1,body1)
        prev=text_obj1
        curr_y=y
        for bullet_point in bullet_points:
            text_obj=ax.text(x,curr_y-5, wrap_text(bullet_point,width), fontsize=fsize,
                       ha='center', va='center', rotation=0,
                       bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))
            connect(ax,text_obj,prev)
            prev=text_obj
            curr_y=curr_y-5

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, 30)
ax.set_ylim(0, 25)
ax.axis('off')
x=15
y=25
width=30
document_title='abc'

paragraphs=form_contexts(tt,0.03)


text_obj1=ax.text(x, y, wrap_text(document_title,width), fontsize=18,
                   ha='center', va='center', rotation=0,
                   bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))

# para(ax,x,y-4,paragraphs[0],text_obj1,width,6)
lr=7
# plt.draw()
for i in range(int(len(paragraphs)/2)):
    para(ax,x-lr,y-4,paragraphs[2*i+1],text_obj1,width,6,8)
    para(ax,x+lr,y-4,paragraphs[2*i],text_obj1,width,6,8)
    lr=lr+14
    

plt.plot()
# Out:
# []

# %%
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
# ax.set_xlim(0, 30)
# ax.set_ylim(0, 30)
# ax.axis('off')
# x=15
# y=30
# width=30
# document_title='abc'

# # paragraphs=form_contexts(tt,0.03)


# text_obj1=ax.text(x, y, (document_title), fontsize=14,
#                    ha='center', va='center', rotation=0,
#                    bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))

# text_obj2=ax.text(x-14, y-5, (document_title), fontsize=14,
#                    ha='center', va='center', rotation=0,
#                    bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))
# text_obj3=ax.text(x+14, y-6, (document_title), fontsize=14,
#                    ha='center', va='center', rotation=0,
#                    bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))
# text_obj4=ax.text(x-28, y-7, (document_title), fontsize=14,
#                    ha='center', va='center', rotation=0,
#                    bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))
# connect(ax,text_obj4,text_obj3)

# %%
# fig, ax = plt.subplots()
# # ax.set_xlim(-100, 100)
# # ax.set_ylim(0, 25)
# ax.axis('off')
# x=15
# y=25
# width=30
# document_title='abc'

# paragraphs=form_contexts(tt,0.03)


# text_obj1=ax.text(x, y, wrap_text(document_title,width), fontsize=14,
#                    ha='center', va='center', rotation=0,
#                    bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))

# # para(ax,x,y-4,paragraphs[0],text_obj1,width,6)
# lr=50
# plt.draw()
# for i in range(int(len(paragraphs)/2)):
#     para(ax,x-lr,y-4,paragraphs[2*i+1],text_obj1,width,6,4)
#     para(ax,x+lr,y-4,paragraphs[2*i],text_obj1,width,6,4)
#     lr=lr+100
    

# plt.plot()
# plt.savefig('my_plot.png')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

screen_width, screen_height = mpl.rcParams['figure.figsize'][0] * mpl.rcParams['figure.dpi'], mpl.rcParams['figure.figsize'][1] * mpl.rcParams['figure.dpi']
fig, ax = plt.subplots(figsize=(2500 / 100, screen_height / 100))  # Dividing by 100 to convert from pixels to inches
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
ax.axis('off')

x = 15
y = 25
width = 30
document_title = 'abc'

paragraphs = form_contexts(pp, 0.03)

text_obj1 = ax.text(x, y, wrap_text(document_title, width), fontsize=14,
                    ha='center', va='center', rotation=0,
                    bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))


lr = 100  


plt.draw()
for i in range(int(len(paragraphs) / 2)):
    para(ax, x - lr, y - 4, paragraphs[2 * i + 1], text_obj1, width, 6, 7)
    para(ax, x + lr, y - 4, paragraphs[2 * i], text_obj1, width, 6, 8)
    lr += 200  

plt.plot()
plt.savefig('my_plot.png')

# %%
pp="""Climate change is one of the most pressing issues facing our planet today. The increasing concentration of greenhouse gases in the atmosphere, primarily due to human activities such as burning fossil fuels and deforestation, is leading to a rise in global temperatures. This phenomenon, known as global warming, has far-reaching effects on the environment, including more frequent and severe weather events, rising sea levels, and disruptions to ecosystems.

To combat climate change, countries around the world are taking various measures. International agreements, such as the Paris Agreement, aim to limit global temperature rise to below 2 degrees Celsius above pre-industrial levels, with efforts to keep it to 1.5 degrees. Nations are also investing in renewable energy sources, such as solar, wind, and hydroelectric power, to reduce dependence on fossil fuels. Additionally, energy efficiency measures and technological innovations, such as electric vehicles and smart grids, are being promoted to reduce carbon emissions.

However, significant challenges remain. Transitioning to a low-carbon economy requires substantial financial investments and policy changes. There is also the need for global cooperation to ensure that all countries, especially developing nations, have access to the resources and technologies necessary for sustainable development. Public awareness and behavioral changes are also crucial in the fight against climate change, as individual actions collectively have a significant impact on reducing carbon footprints.

Despite the challenges, there are reasons for optimism. Advances in technology are making renewable energy more affordable and efficient. Grassroots movements and youth activism are bringing greater attention to the issue and pushing for more ambitious climate policies. With continued efforts and cooperation, it is possible to mitigate the worst effects of climate change and build a more sustainable future for all."""

# %%
# import matplotlib.pyplot as plt
# import matplotlib as mpl

# # Get the screen size
# screen_width, screen_height = mpl.rcParams['figure.figsize'][0] * mpl.rcParams['figure.dpi'], mpl.rcParams['figure.figsize'][1] * mpl.rcParams['figure.dpi']

# # Create a figure with the screen size
# fig, ax = plt.subplots(figsize=(2500 / 100, screen_height / 100))  # Dividing by 100 to convert from pixels to inches

# # Adjust the figure layout to fill the screen
# plt.subplots_adjust(left=0, right=1, top=1, bottom=0)

# # Hide the axes
# ax.axis('off')

# # Your existing plot code
# x = 15
# y = 25
# width = 30
# document_title = 'abc'

# # Assuming paragraphs are obtained from form_contexts function
# paragraphs = form_contexts(pp, 0.03)

# # Draw the main title text box
# text_obj1 = ax.text(x, y, wrap_text(document_title, width), fontsize=14,
#                     ha='center', va='center', rotation=0,
#                     bbox=dict(boxstyle="round,pad=0.5", facecolor='wheat', edgecolor='black'))

# # Initialize the horizontal offset for paragraph text boxes
# lr = 100  # Increase the initial horizontal offset
# plt.draw()
# # Keep the vertical position constant and adjust horizontal spacing
# if(len(paragraphs)%2==1):  
#     for i in range(int(len(paragraphs) / 2)):
#         para(ax, x - lr, y - 4, paragraphs[2 * i + 1], text_obj1, width, 6, 7)
#         para(ax, x + lr, y - 4, paragraphs[2 * i], text_obj1, width, 6, 8)
#         lr += 200  # Increase the increment step for horizontal offset
# else:
#     para(ax, x, y - 4, paragraphs[0], text_obj1, width, 6, 7)
#     lr+=200
#     for i in range(1,int((len(paragraphs)+1)/2)):
#         para(ax, x - lr, y - 4, paragraphs[2 * i - 1], text_obj1, width, 6, 7)
#         para(ax, x + lr, y - 4, paragraphs[2 * i], text_obj1, width, 6, 8)
#         lr += 200  # Increase the increment step for horizontal offset

# plt.plot()
# plt.savefig('my_plot.png')

# %%
 for i in range(int(3/ 2)):
        print(i)
# Out:
# 0

# %%
print(int(len(paragraphs) / 2))
# Out:
# 2

# %%
(len(paragraphs))
# Out:
# 4

# %%
paragraphs
# Out:
# ['Climate change is one of the most pressing issues facing our planet today. The increasing concentration of greenhouse gases in the atmosphere, primarily due to human activities such as burning fossil fuels and deforestation, is leading to a rise in global temperatures. This phenomenon, known as global warming, has far-reaching effects on the environment, including more frequent and severe weather events, rising sea levels, and disruptions to ecosystems. To combat climate change, countries around the world are taking various measures. International agreements, such as the Paris Agreement, aim to limit global temperature rise to below 2 degrees Celsius above pre-industrial levels, with efforts to keep it to 1. 5 degrees.',
# ...
