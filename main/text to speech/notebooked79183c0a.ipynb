# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS

text = "नमस्ते, आप कैसे हैं?"
tts = gTTS(text=text, lang='hi')
tts.save("output_hi.mp3")
