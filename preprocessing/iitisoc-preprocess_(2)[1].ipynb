# %%
                                                                pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in /opt/conda/lib/python3.10/site-packages (1.24.7)
# Requirement already satisfied: PyMuPDFb==1.24.6 in /opt/conda/lib/python3.10/site-packages (from pymupdf) (1.24.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install einops flash_attn
# Out:
# Requirement already satisfied: einops in /opt/conda/lib/python3.10/site-packages (0.8.0)
# Requirement already satisfied: flash_attn in /opt/conda/lib/python3.10/site-packages (2.5.9.post1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from flash_attn) (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->flash_attn) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->flash_attn) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->flash_attn) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->flash_attn) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->flash_attn) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->flash_attn) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->flash_attn) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in /opt/conda/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from python-docx) (5.2.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /opt/conda/lib/python3.10/site-packages (from python-docx) (4.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import fitz  
from PIL import Image, ImageDraw, ImageFont
import io
from io import BytesIO
import pytesseract  
import torch 
import requests  
from transformers import Blip2Processor, Blip2ForConditionalGeneration, PegasusForConditionalGeneration, PegasusTokenizer, AutoProcessor, AutoModelForCausalLM 
from docx import Document 
from docx.shared import Inches  
import tempfile  
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import BartForConditionalGeneration, BartTokenizer
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from transformers import BartTokenizer
import numpy as np 
import pandas as pd 
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# 2024-06-27 17:59:38.936712: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 17:59:38.936762: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 17:59:38.938170: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = AutoModelForCausalLM.from_pretrained("microsoft/Florence-2-large", trust_remote_code=True).to(device)
processor = AutoProcessor.from_pretrained("microsoft/Florence-2-large", trust_remote_code=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
def run_example(image, task_prompt, text_input=None):
    if text_input is None:
        prompt = task_prompt
    else:
        prompt = task_prompt + text_input
    inputs = processor(text=prompt, images=image, return_tensors="pt").to(device)
    generated_ids = model.generate(
        input_ids=inputs["input_ids"],
        pixel_values=inputs["pixel_values"],
        max_new_tokens=1024,
        num_beams=3
    )
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]
    parsed_answer = processor.post_process_generation(generated_text, task=task_prompt, image_size=(image.width, image.height))
    caption = parsed_answer["<MORE_DETAILED_CAPTION>"]
    return caption

# %%
def pdf_doc(pdf_document):
    doc = fitz.open(pdf_document)

    page_text_list = []
    for page_number in range(len(doc)):
        page = doc.load_page(page_number)  
        image_list = page.get_images(full=True)  

        page_text = page.get_text()
        page_text_combined = page_text

        
        for img_index, img in enumerate(image_list):
            xref = img[0] 
            base_image = doc.extract_image(xref)  
            image_bytes = base_image["image"]
            
            image = Image.open(io.BytesIO(image_bytes)).convert('RGB')
            
            prompt = "<MORE_DETAILED_CAPTION>"
            generated_caption = run_example(image, prompt)

            combined_text = f"\n\nImage {img_index + 1}:\nCaption: {generated_caption}\n"

            page_text_combined += combined_text

        page_text_list.append(page_text_combined)
    return page_text_list

# %%
def docx_doc(docx_document):
    doc = Document(docx_document)
    doc_text_list = []
    for para in doc.paragraphs:
        doc_text_list.append(para.text)

        for run in para.runs:
            if run.element.xml.find("pic:blipFill") != -1:
                image = run.element.xpath(".//a:blip")[0]
                image_data = image.get("{http://schemas.openxmlformats.org/officeDocument/2006/relationships}embed")
                image_part = doc.part.related_parts[image_data]
                image_bytes = image_part.blob

                image = Image.open(io.BytesIO(image_bytes)).convert('RGB')
                prompt = "<MORE_DETAILED_CAPTION>"
                generated_caption = run_example(image, prompt)
                combined_text = f"Caption: {generated_caption}\n"
                doc_text_list.append(combined_text)
    return doc_text_list

# %%
def determine_file_type(file_path):
    _, file_extension = os.path.splitext(file_path)
    if file_extension.lower() == '.docx':
        return 'docx'
    elif file_extension.lower() == '.pdf':
        return 'pdf'
    else:
        return 'unknown'

# %%
def get_text(path):
    text_each_page=[]
    file_type=determine_file_type(path)
    if file_type=='pdf':
        text_each_page=pdf_doc(path)
    elif file_type=='docx':
        text_each_page=docx_doc(path)
    else :
        print("invalid file type")
    return text_each_page

# %%
def preprocess_text(text):
    text = text.lower()
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return ' '.join(tokens)

# %%
def process_text_in_sentence_chunks(path, max_chunk_size):
    text=('\n'.join(page for page in get_text(path)))
    sentences = text.replace("\n", " ") 
    sentences = nltk.sent_tokenize(sentences)

    current_chunk = ""
    text_list = []
    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_chunk_size:
            current_chunk += " " + sentence
        else:
              text_list.append(current_chunk.strip())
              current_chunk = sentence

    if current_chunk:
        text_list.append(current_chunk.strip())
    return text_list

# %% [markdown]
# # Models****

# %%
model_name = 't5-large'
tokenizer1 = T5Tokenizer.from_pretrained(model_name)
model1 = T5ForConditionalGeneration.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model1.to(device)

def generate_summary_t5(text, max_length=60):
    preprocess_text = text.strip().replace("\n", " ")
    t5_prepared_text = "summarize: " + preprocess_text

    tokenized_text = tokenizer1.encode(t5_prepared_text, return_tensors="pt", max_length=512, truncation=True)
    tokenized_text = tokenized_text.to(device)
    summary_ids = model1.generate(tokenized_text, max_length=max_length, min_length=5, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer1.decode(summary_ids[0], skip_special_tokens=True)

    return summary
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model_name = "facebook/bart-large-cnn"
tokenizer2 = BartTokenizer.from_pretrained(model_name)
model2 = BartForConditionalGeneration.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model2.to(device)


def generate_summary_bart(input_text):
    inputs = tokenizer2(input_text, return_tensors="pt", max_length=1024, truncation=True).to("cuda")
    summary_ids = model2.generate(inputs['input_ids'], 
                                 max_length=80, 
                                 min_length=5, 
                                 length_penalty=2.0, 
                                 num_beams=4, 
                                 early_stopping=True)
    summary = tokenizer2.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
model_name = "google/pegasus-large"
tokenizer3 = PegasusTokenizer.from_pretrained(model_name)
model3 = PegasusForConditionalGeneration.from_pretrained(model_name)


def generate_summary_pegasus(input_text, max_input_length=1024, max_summary_length=60, min_summary_length=15):
    inputs = tokenizer3(input_text, return_tensors="pt", max_length=max_input_length, truncation=True)
    summary_ids = model3.generate(inputs['input_ids'], 
                                 max_length=max_summary_length,
                                 min_length=min_summary_length,  
                                 num_beams=4, 
                                 length_penalty=2.0, 
                                 early_stopping=True)
    summary = tokenizer3.decode(summary_ids[0], skip_special_tokens=True)
    return summary
# Out:
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-large and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
path="/kaggle/input/bsebse/BSE102_Lecture 3_Chemical basis of life.pdf"

# %%
input_text=process_text_in_sentence_chunks(path,512)
for text in input_text:
    print(generate_summary_t5(text))
# Out:
# BSE 102 Bioscience Spring 2024 The Chemical Basis of Life Instructor: Dr. sunil Kumar boda Assistant professor department of biosciences & biomedical engineering IIT Indore.
# the book is surrounded by a banner with the words "IIT Indore" written in Hindi. below the book, there are two lines of text in Hindi, which translates to "Indian Institute of technology Indore" the emblem is a symbol of knowledge and knowledge
# elements are substances that cannot be further broken down to other substances by ordinary chemical means. compounds are substances containing two or more elements combined in a fixed ratio.
# 2Na + Cl2 2 NaCl; (both Na and Cl are corrosive, but. NaCl is edible!)
# major elements in the human body: C, O, H, N, Ca, P (make up 99% of body weight) minor elements ( 1 wt%): K, S, Na, Cl, Mg (for nerve signaling and chemical reactions) trace elements (
# the infographic shows a man standing with his back to the viewer. he is wearing a red t-shirt, black shorts, and colorful socks. the infographic is divided into three sections.
# the chart also includes information about the different elements and their properties. trace elements are common additives to food and water. iodine is an essential component of the hormones thyroxine (T4 - inactive) and triiodoth
# iodine deficiency leads to abnormal swelling of the thyroid gland leading to a condition called goiter. most serious effects of iodine deficiency occur during fetal development and childhood.
# iron (Fe) makes up only 0.004 wt% of body weight. it is vital for energy processing and transport of oxygen. iron rich foods include meat, fish, poultry, eggs, green, legumes, raisins.
# excess fluoride in drinking water can cause fluorosis, a condition of brown stained teeth. excess/ overload of trace elements can lead to accidental fatal poisoning. recommended dietary allowances (RDA) of trace elements are based on gender (male/ female
# the woman appears to be in her late 60s or early 70s. the text on the image reads "goiter, a symptom of iodine deficiency" the image shows a variety of food items that are rich in iron.
# image shows a piece of raw meat, possibly pork or beef. the meat is pink in color and looks to be seasoned with herbs and spices. the background is white.
# mouthwash and toothpaste are examples of dietary deficiencies. a table lists the different types of deficiencies and their properties.
# the physical functions of the dietary deficiencies are: - selenium (se) - zinc (zn) - copper (c) helps regulate the metabolism and metabolism of the human body. selenium is a component of the body's immune system
# the image also includes a brief description of each type of deficiency and how they can affect the overall overall overall health of the individual.
# Atom = proton (p+) + neutron (n) + electron (e-) Atomic Number = no. of protons Mass Number = no. of neutrons Atomic Mass = mass of protons + mass of neutrons + mass of electrons Mass of
# decaying isotopes can pose serious risks to living organisms. radioactive isotopes can be helpful, as in their use in dating fossils. living organisms cannot distinguish between isotopes.
# biologists often use radioactive tracers to follow molecules as they undergo chemical changes in an organism. 14CO2 transforming into different metabolites during photosynthesis of carbohydrates.
# the nucleus is represented by a pink circle with a plus sign in the center. on the right side, there is an electron cloud, which represents the nucleus of the atom. inside the nucleus, there are two electrons, one pink and
# image suggests that the image is meant to illustrate the relationship between the two models. there is also a note on the image that reads "note that these models are not to scale"
# DNA, not protein contains the genetic code – proven by radioisotope labeling Griffith’s experiment (1928).
# after infection by 32P-labeled phage, radioactivity was found only in the transduced bacteria. after infection with 35S-labeled phage, radioactivity is found only in the supernatant that remains after the bacteria are removed.
# in the first stage, there are six rats, each with a different color - R, S, and R. the rats are shown in a light brown color and are arranged in a grid-like pattern. the second stage is labelled "S",
# the image shows the different types of heat treatments that can be used to treat the rats. the third stage is titled "heat-treated" and has a yellow sphere with a red arrow pointing towards it. the fourth stage is described as "heat
# diagram shows process of DNA, heat-treated S, and protease. diagram is divided into four sections, each representing a different stage of process. first section shows the DNA molecule, which is represented by a yellow circle.
# the image shows a group of yellow spheres, which are likely the nucleotides of the molecule. the fourth section shows another brown mouse with a black arrow pointing towards the left side, representing the nucleotide.
# image is a diagram that shows the process of centrifugation of bacteria in cells. it is divided into two sections. the first section on the left shows a sulfur-labeled protein capsule. the second section on the right shows a cell inside it
# the capsule is labeled as "bacteriophages" and the cell inside the capsule is labeled as "phosphorus labeled DNA (green)" in the second section, there is an infection of the bacteria. the infection is represented by a green line that runs
# the diagram shows how bacteria can be used to differentiate between different types of bacteria and how they interact with each other. the diagram also has a label that reads "1"
# some radioactive isotopes are used for treatment. eg: the body uses iodine to make a thyroid hormone.
# radioactive iodine accumulates in the thyroid, so it can be used to kill thyroid cancer cells. substances that the body metabolizes, such as glucose or oxygen, may also be labeled. PET scan can produce images of areas of the body with
# Alzheimer is a neurodegenerative disease, wherein the brain becomes riddled with deposits (plaques) of a protein called beta-amyloid. researchers have synthesized a radioactively labeled protein molecule called PIB that binds
# image shows two MRI images of the brain, one in blue and the other in yellow. the blue image shows the brain in detail, while the yellow image shows it in color. both images are labeled with the text "healthy person" and "alzheimer
# uncontrolled exposure to high levels of radiation can be lethal. particles and energy thrown off by radioactive atoms can damage molecules, especially DNA.
# explosion of nuclear reactor in Chernobyl, Ukraine, in 1986 released large amounts of radioactive isotopes into the environment. a few dozen people died from acute radiation poisoning within a few weeks of the accident. increased rates of thyroid cancer in children
# natural sources of radiation can also pose a threat. radon is the second-leading cause of lung cancer in the united states. homeowners can buy a radon detector or hire a company to test their home.
# technology exists to remove radon from home if levels are found to be unsafe. Marie curie died of aplastic pernicious anemia due to her years of exposure to radiation during her work.
# the diagram is divided into two columns, with the left column representing the element name and the right column representing half-life units. the elements are arranged in a grid-like pattern, with each element represented by a square box.
# the atomic number is 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, and 92. distribution of electrons determine an atom's chemical properties.
# Ionic bond: complete electron transfer between two atoms. covalent bond: sharing of electrons between two atoms.
# photosynthesis: 6CO2 + 6H2O hvC6H12O6 + 6O2 Aerobic respiration: C6H12O6 + 6O2 6CO2 + 6H2O + ATP
# the diagram is a flowchart that shows the process of photosynthesis. photosynthesis is a process where photosynthesis takes place in the atmosphere of a plant. the diagram shows a sun with a carbon dioxide molecule in the center, representing the energy of the
# photosynthetic organisms use the energy to sunlight to manufacture glucose and other organic products, which heterotrophic cells use as energy and carbon sources. theory of spontaneous generation: if food was left to rot, it would generate living organisms like microbes, maggot
# Darwin’s theory of evolution suggested that simpler life forms gave rise to complex organisms. but pasteur said ‘life only comes from life’.
# abiogenic factors above in water gave rise to biomolecules (amino acids, lipids, nucleic acids, carbohydrates) all above theories were only speculations without proof.
# the top section of the tree has a list of different types, including birds, reptiles, mammals, amphibians, land plants, and seaweed. there are also illustrations of animals such as a bird, a zebra, a ladybug, and
# seaweed is a type of seaweed that is native to the ocean floor. there is also an illustration that shows a snail, a crab, a jellyfish, a starfish, and an octopus. the image is labeled with
# simulated the origins of life on earth by using – • water representing the oceans • reducing earth’s atmosphere consisting majorly of gases like CH4, NH3, H2 and H2O (water vapor) after a week, the water turned
# amino acids, lipids and sugar are found on other planets, asteroids in our solar system and even beyond within our galaxy.
# it consists of a white sphere with a red arrow pointing towards it, representing the electrical spark. there are two pipes connected to the sphere, one on the left side and the other on the right side. the pipes are connected to each other by
# the diagram appears to be a representation of the process of electrical spark lightning. spark lightning is a type of lightning that is used to generate electricity from a source of light.
# experiment proved the Oparin-haldane chemical origin of life. free atoms of C, H, O, N • abiotic synthesis of monomers from simple inorganic gases like H2, CH4, NH3 and H2O.
# monomers included amino acids, purines, pyrimidines, monosaccharides, fatty acids and glycerol. polymers include proteins, nucleic acids, lipids and polysaccharides.
# first cell probably used inorganic fuels produced by chemosynthesis for ATP generation: FeS + H2S ---FeS2 + H2 Figure 1-37, Landmarks in the evolution of life on earth lehninger.
# the book is divided into six sections, each representing a different step in the process. the first section is titled "Prebiotic formation of simple compounds, including nucleotides" the second section is labeled "Production of short RNA molecules with random sequences
# the process is related to DNA genome translation and protein catalysts. a label at the bottom of the flowchart reads "Genomic RNA begins to be copied into DNA"
# a table shows the different types of eukaryotes and their properties. the left column represents the number of different species of organisms. the right column represents their characteristics.
# the characteristics include: 1,500, 2,000, and 3,000. there are also three types of photosynthetic O2 producing cyanobacteria. there is also a section titled "Formation of oceans and continents"
# few aerobic bacteria evolved into mitochondria of modern eukaryotes. photosynthetic cyanobacteria became plastids, chloroplasts of green algae.
# each section represents a different type of chromosome. nuclei are responsible for storing nuclei in the nucleus of the cell. the nuclei are then released into the cell, which releases nuclei into the mitochondria.
# the image also shows the mitochondrion, which acts as a catalyst for the cell's growth and development. in the center of the image, there are four chromosomes, each with a different color - blue, green, and white.
# the white chromosomes represent chloroplasts, which are the cells that make up the cell membrane. the diagram also includes text that explains the process of photosynthesis and how photosynthesis can be used.

# %%
input_text=process_text_in_sentence_chunks(path,900)
for text in input_text:
    print(generate_summary_bart(text))
# Out:
# The logo is a circular emblem with a blue background and a white border. In the center of the emblem, there is an open book with a sunburst design around it.
# Organisms are composed of elements, usually combined into compounds. Matter – occupies space and has mass. Three physical states of matter – solid, liquid and gas. All forms of matter are fundamentally composed of chemical elements.
# The elements of the human body are C, O, H, N, Ca, P (make up 99% of body weight) Minor elements: K, S, Na, Cl, Mg (for nerve signaling and chemical reactions) Trace elements: B, Cr, Cu, F, I, Fe, Mn, Mo, Se, Si, Sn, V, Zn
# He is standing with one leg slightly bent at the knee and the other leg extended behind him. The infographic is divided into three sections. The chart also includes information about the different elements and their properties.
# Iodine deficiency leads to abnormal swelling of the thyroid gland leading to a condition called goiter. Iron deficiency anemia occurs due to lack of iron to produce hemoglobin. Iron rich foods include meat, fish, poultry, eggs, green, legumes, raisins, etc.
# Excess fluoride in drinking water can cause fluorosis, a condition of brown stained teeth. Excess/ overload of trace elements can lead to accidental fatal poisoning. Recommended dietary allowances (RDA) of trace Elements are based on gender (male/ female) and age.
# Next to the eggs, there is a pile of dried raisins. In the center of the table, there appears to be a large piece of raw meat, possibly pork or beef.
# The table is divided into three columns and three rows. The first column is titled "Physical Functions" and lists the physical functions of the dietary deficiencies. There are also several other physical functions listed in the table, such as the body, the brain, and the brainstem.
# Atom means ‘indivisible’ but physicists split atom into sub-atomic particles. A radioactive isotope is one in which nucleus decays spontaneously. Radiation from decaying isotope can damage cellular molecules.
# Living organisms cannot distinguish between isotopes. So, they uptake both normal and radioactive compounds similarly. Biologists often use radioactive tracers to follow molecules as they undergo chemical changes.
# Inside the nucleus, there are two electrons, one pink and one black, representing protons. The protons are represented by the plus sign, while the neutrons represent the electrons. There is also a note on the image that reads "Note that these models are not to scale"
# DNA, not protein contains the genetic code – proven by radioisotope labeling. Viral DNA was labelled with 32P and protein with 35S. After E.coli infection by 32P-labeled phage, radioactivity was found only in the transduced bacteria.
# In contrast, after infection with 35S-labeled phage, radioactivity is found only in the supernatant that remains after the bacteria are removed.
# The diagram is divided into four sections, each representing a different stage of the process. The first section shows the DNA molecule, which is represented by a yellow circle with the letters "DNA" and "heat-treated" written on it.
# The first section on the left shows a sulfur-labeled protein capsule with a cell inside it. The second section shows a group of yellow spheres, which are likely the nucleotides of the molecule. The fifth section shows that the molecule is protease, and the sixth section shows how it is treated with a heat-treated S.
# The capsule is labeled as "bacteriophages" and the cell inside the capsule is labelled as "phosphorus labeled DNA" In the second section, there is an infection of the bacteria. The infection is represented by a green line that runs from the cell to the cell. The cell is shown in the center of the image.
# Radioactive isotopes may also be used to tag chemicals that accumulate in specific areas of the body. Substances that the body metabolizes, such as glucose or oxygen, may be labeled with a radioactive isotope. Some radioactive isotopes are used for treatment.
# PET (positron- emission tomography) scan can produce images of areas of the body with high metabolic activity. PET is useful for diagnosing certain heart disorders and cancers and for basic  research on the brain. Alzheimer is a neurodegenerative disease, wherein the brain becomes riddled with deposits (plaques) of a protein called beta-amyloid.
# Both images are labeled with the text "Healthy person" and "Alzheimer's patient" The image also includes a text that reads "Figure 2.4B PET images of brains of a healthy person (left) and a person with Alzheimer's disease (right) Red and yellow colors indicate high levels of PIB bound to beta-amyloid plaques" This suggests
# Radon, a radioactive gas, is the second-leading cause of lung cancer in the U.S. Homeowners can buy a radon detector or hire a company to test their home to ensure that radon levels are safe.
# Marie Curie died of aplastic pernicious anemia (body stops producing blood cells) due to her years of exposure to radiation during her work.
# At the top of the diagram, there is a title that reads "The Uranium -238 Decay Chain" below it, there are numbers that indicate the atomic decay chain. The atomic number is 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, and 92.
# Eg: H2, O2, CH4,  H2O • Hydrogen bonds: weak bonds between polar molecules; important in the chemistry of life. Chemical reactions make and break chemical bonds 2H2 + O2 2H2O  Above reaction is an explosive reaction (fortunately does not occur in cells)
# The diagram shows a sun with a carbon dioxide molecule in the center. The molecule is represented by a yellow circle with a red line connecting it to the carbon dioxide molecules. At the bottom of the diagram, there is a text that explains that photosynthesis is the ultimate source of all biological en-ergy.
# Oparin-Haldane theory of abiogenesis (1929): Organic molecules needed for life could be formed from abiotic materials in the presence of energy. Oparin’s primordial soup: abiogenic factors above in water gave rise to biomolecules needed to form cells. All above theories were only speculations without proof.
# There are also illustrations of animals such as a bird, a zebra, a ladybug, and a turtle. The animals are arranged in a circular pattern around the tree. There is also an illustration that shows a snail, a crab, a jellyfish, a starfish, and an octopus.
# Miller – Urey experiment (1953) Miller simulated the origins of life on earth by reducing earth’s atmosphere. After a week, the water turned brown and contained organic biomolecules. Amino acids, lipids and sugar are found on  other planets, asteroids in our solar system and even beyond within our galaxy.
# In one set of experiments, Miller included H2S from atmospheric volcanoes, which accounted for formation of sulfur containing amino acids and subsequent disulfide links in proteins.
# On the bottom left corner, there are two purple pipes, one of which is connected with a purple pipe. The red circle represents the light source, while the blue circle represents a blue sphere.
# Monomers included amino acids, purines, pyrimidines, monosaccharides, fatty acids and glycerol. Monomers combine to form polymers. Proteins, nucleic acids, lipids and polysaccharides form coacervates. Biomolecules are surrounded by a lipid membrane.
# Figure 1-36, A Possible RNA scenario world First cell probably used inorganic fuels produced by chemosynthesis for ATP generation. Figure 1-37, Landmarks in the evolution of life on earth.
# The first section is titled "Prebiotic formation of simple compounds, including nucleotides, from components of Earth's primitive atmosphere" The second section is labeled "Production of short RNA molecules with random sequences" The third section is "Selective replication of self-duplicating catalytic RNA segments" The fourth section is labelled "Synthesis of specific peptides, catalyzed
# The table is divided into two columns, with the left column representing the number of different species of organisms. There are also three types of photosynthetic O2 producing cyanobacteria. At the bottom of the table, there is a section titled "Formation of oceans and continents"
# Few aerobic bacteria evolved into mitochondria of modern eukaryotes. Photosynthetic cyanobacteria became plastids, chloroplasts of green algae, the ancestors of modern plant cells.
# The image also shows the mitochondrion, which acts as a catalyst for the cell's growth and development. In the center of the image, there are four chromosomes, each with a different color - blue, green, and white. These chromosomes are arranged in a circular pattern, representing the different stages of the cycle.

# %%
input_text=process_text_in_sentence_chunks(path,512)
for text in input_text:
    print(generate_summary_pegasus(text))
# Out:
# It is a circular emblem with a blue background and a white border.
# Below the book, there are two lines of text in Hindi, which translates to "Indian Institute of technology Indore".
# Organisms are composed of elements, usually combined into compounds Matter – occupies space and has mass Three physical states of matter – solid, liquid and gas All forms of matter – rocks, water, air and biological systems are fundamentally composed of chemical elements.
# Eg: 2Na + Cl2 2 NaCl; (Both Na and Cl are corrosive, but NaCl is edible!)
# 2H2 + O2 2H2O Compounds in living organisms comprise of 3 or 4 elements: • Carbohydrates: Carbon (C), Oxygen (O), Hydrogen (H) • Proteins: Carbon (C), Oxygen (O), Hydrogen (H), Nitrogen
# It shows a silhouette of a man standing with his back to the viewer, facing the viewer.
# Trace elements are common additives to food and water Iodine is an essential component of the hormones thyroxine (T4 - inactive) and triiodothyronine (T3 - active) produced by the thyroid glands.
# Iodine deficiency leads to abnormal swelling of the thyroid gland leading to a condition called goiter.
# Iron deficiency anemia occurs due to lack of iron to produce hemoglobin. In pregnant women, iron deficiency puts the baby at the risk of developmental delays.
# Recommended dietary allowances (RDA) of trace elements are based on gender (male/ female) and age (infants/ adults) Image 1: Caption: The image is a portrait of an elderly woman from Burma.
# On the left side of the image, there are two eggs, a bunch of green beans, and a small bowl of nuts.
# The toothbrush has a green handle and white bristles, and the toothpaste is a light blue color.
# Importance of trace elements PN: Parenteral nutrition – feeding nutrients through intravenous/ non- gastrointestinal route Image 1: Caption: The image is a table that lists the different types of dietary deficiencies and their properties.
# The physical functions are: - Selenium (S) - Zinc (Zn) As a component of the body's immune system, the body is responsible for regulating the flow of nutrients and nutrients in the body.
# There are also several other physical functions listed in the table, such as the body, the brain, and the brainstem.
# of neutrons Atomic Mass = Mass of protons + Mass of neutrons + Mass of electrons Mass of proton = Mass of neutron  1 Da Mass of electron = 1/2000 Mass of proton; m (e-)  m (p+) So, Atomic Mass  Mass of
# Radiation from decaying isotope can damage cellular molecules and thus can pose serious risks to living organisms.
# The model on the left is a nucleus, which is a type of atom with two protons and two neutrons.
# The nucleus is represented by a pink circle with a plus sign in the center, representing the nucleus.
# There is also a note on the image that reads "Note that these models are not to scale; they greatly overestimate the size of the nucleus in relation to the electron cloud." This suggests that the image is meant to illustrate the relationship between the two models.
# DNA, not protein contains the genetic code – proven by radioisotope labeling Griffith’s experiment (1928) – bacterial transformation Two strains of the bacterium Streptococcus pneumoniae: • R-strain (rough colonies) – not virulent; did not kill mice • S-strain (
# In contrast, after infection with 35S-labeled phage, radioactivity is found only in the supernatant that remains after the bacteria are removed.
# The first stage is labeled "R" and shows a yellow circle with a black arrow pointing to it, indicating the direction of the heat treatment process.
# The third stage is titled "heat-treated" and has a yellow sphere with a red arrow pointing towards it.
# The first section shows the DNA molecule, which is represented by a yellow circle with the letters "DNA" and "heat-treated" written on it.
# The fourth section shows another brown mouse with a black arrow pointing towards the left side, representing the nucleotide.
# The image also shows the interaction between the two molecules, with the first molecule on the left and the second on the right.
# The infection is represented by a green line that runs from the cell to the cell.
# The arrows are pointing towards the cells, indicating that the infection is in the process.
# Radioactive isotopes in medical diagnosis and treatment Radioactive isotopes may also be used to tag chemicals that accumulate in specific areas of the body.
# PET (positron- emission tomography) scan can produce images of areas of the body with high metabolic activity.
# Researchers have synthesized a radioactively labeled protein molecule called PIB (Carbon-11- labeled Pittsburgh Compound B) that binds to beta-amyloid plaques and can be detected on a PET scan.
# Image 1: Caption: The image shows two MRI images of the brain, one in blue and the other in yellow. The blue image shows the brain in detail, while the yellow image shows it in color.
# The particles and energy thrown off by radioactive atoms can damage molecules, especially DNA.
# Increased rates of thyroid cancer in children exposed to the radiation have been reported.
# Radon, a radioactive gas, is the second-leading cause of lung cancer in the United States.
# Image 1: Caption: The image is a diagram of the Uranium-238 Decay Chain, which is a periodic table that shows the atomic number of the elements in the periodic table.
# The second column is titled "Element Names" and lists the elements that are represented in the diagram.
# Chemical bonds in biomolecules Distribution of electrons determine an atom’s chemical properties.
# Eg: NaCl • Covalent bond: Sharing of electrons between two atoms.
# Eg: H2, O2, CH4, H2O • Hydrogen bonds: weak bonds between polar molecules; important in the chemistry of life Chemical reactions make and break chemical bonds 2H2 + O2 2H2O Above reaction is an explosive reaction (fortunately does not occur
# The diagram shows a sun with a carbon dioxide molecule in the center, representing the energy of the sun.
# Theory of spontaneous generation: If food was left to rot, it would generate living organisms like microbes, maggots (larvae of flies) and subsequently higher organisms like rats.
# Oparin-Haldane theory of abiogenesis (1929): Organic molecules needed for life could be formed from abiotic materials in the presence of energy (lightning, heat and UV-light) under reducing conditions of early earth’s atmosphere (low levels of O2; major composition of
# Image 1: Caption: The image is a diagram of a tree with different types of plants and animals.
# The animals are arranged in a circular pattern around the tree, with the birds at the top and the reptiles at the bottom.
# On the right side, there is an illustration of a seaweed plant, which is a type of seaweed that is native to the ocean floor.
# Miller – Urey experiment (1953) Miller simulated the origins of life on earth by using – • Water representing the oceans • Reducing earth’s atmosphere consisting majorly of gases like CH4, NH3, H2 and H2O (water vapor) • Energy source – sunlight, geothermal
# Prebiotic chemistry – amino acids, lipids and sugar are found on other planets, asteroids in our solar system and even beyond within our galaxy.
# There are two pipes connected to the sphere, one on the left side and the other on the right side.
# In the center of the diagram, there is a red circle with a blue wave-like pattern, representing a light source.
# Miller – Urey experiment proved the Oparin-Haldane chemical origin of life Step1 • Free atoms of C, H, O, N • Abiotic synthesis of monomers from simple inorganic gases like H2, CH4, NH3 and H2O.
# • Monomers included amino acids, purines, pyrimidines, monosaccharides, fatty acids and glycerol Step2 • Monomers combine to form polymers • Proteins, nucleic acids, lipids and polysaccharides Step3 • Formation of coacervates • Biomolecules surrounded
# Figure 1-36, A Possible RNA scenario world First cell probably used inorganic fuels produced by chemosynthesis for ATP generation: FeS + H2S ---FeS2 + H2 Figure 1-37, Landmarks in the evolution of life on earth Lehninger, Principles of Biochemistry,
# The second section is labeled "Production of short RNA molecules with random sequences".
# The sixth section is called "Primitive translation system develops, with RNA genome and RNA-protein catalysts".
# The table is divided into two columns, with the left column representing the number of different species of organisms and the right column representing their characteristics.
# The appearance of protists, the first euaryotes, and the development of O2-rich atmosphere There are also three types of photosynthetic O2 producing cyanobacteria At the bottom of the table, there is a section titled "Formation of oceans and continents" which provides further
# Image 1: Caption: The image is a diagram that shows the different types of chromosomes and their functions.
# The nuclei are responsible for storing nuclei in the nucleus of the cell.
# In the center of the image, there are four chromosomes, each with a different color - blue, green, and white.
# The diagram also includes text that explains the process of photosynthesis and how photosynthesis can be used to convert photosynthesis into photosynthesis.
